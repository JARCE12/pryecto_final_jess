# %%
import pandas as pd
from pandas import read_excel

df = read_excel('pryecto f_jess.xls', sheet_name ='Sheet1')
print(df)
# Out:
#      No.      CEDULA            APELLIDOS              NOMBRES  \
# 0      1    52049789        ACOSTA CASTRO          MARIA LUISA
# 1      2    93361475       ACOSTA RAMIREZ       RAFALE ALFREDO
# 2      3    79427921        ALFARO PATIÑO      JAVIER GREGORIO
# 3      4    52823876       ALONSO FAJARDO        NYDIA SOLANGE
# 4      5  1023869424      ALVAREZ FAJARDO        KAREN GISELLE
# 5      6    80394134    ALVAREZ MALDONADO       HECTOR ORLANDO
# 6      7    52203673         AMAYA CASTRO        MARTHA ISABEL
# 7      8    52172187         ANGEL OSORIO         AMANDA LUCIA
# 8      9    18203250               ARANGO       CARLOS ENRIQUE
# 9     10    79529340     ARDILA VELASQUEZ          JUAN CARLOS
# 10    11    12906217    ARELLANO PALACIOS               HECTOR
# 11    12    79291749    ARISTIZABAL GOMEZ          JUAN CARLOS
# 12    13    79277802     AVELLANEDA RIAÑO      KILTON HUMBERTO
# 13    14    51783001      AVILA MATAMOROS          DIANA ROCIO
# ...

# %%
print(df.head())
# shows headers with top 5 rows
# Out:
#    No.      CEDULA        APELLIDOS          NOMBRES  \
# 0    1    52049789    ACOSTA CASTRO      MARIA LUISA
# 1    2    93361475   ACOSTA RAMIREZ   RAFALE ALFREDO
# 2    3    79427921    ALFARO PATIÑO  JAVIER GREGORIO
# 3    4    52823876   ALONSO FAJARDO    NYDIA SOLANGE
# 4    5  1023869424  ALVAREZ FAJARDO    KAREN GISELLE
#
#                           CARGO  CIUDAD TELEFONO  \
# 0  AUXILIAR DE SERVICIO A BORDO  BOGOTA      NaN
# 1  ESPECIALISTA DE AVIACION III  BOGOTA  4238530
# 2   PROFESIONAL ESPECIALIZADO I  BOGOTA  4238530
# 3                    TECNICO II  BOGOTA  4238530
# 4   PROFESIONAL ESPECIALIZADO I  BOGOTA  4292300
#
#                       Unnamed: 7
# 0        maria.acosta@satena.com
# 1       RAFALE.ACOSTA@SATENA.COM
# 2       JAVIER.ALFARO@SATENA.COM
# 3        SOLANGEALONSO@GMAIL.COM
# 4  GISELLE.ALVAREZ0416@GMAIL.COM

# %%
print(df.ix[1:3])
# Out:
#    No.    CEDULA       APELLIDOS          NOMBRES  \
# 1    2  93361475  ACOSTA RAMIREZ   RAFALE ALFREDO
# 2    3  79427921   ALFARO PATIÑO  JAVIER GREGORIO
# 3    4  52823876  ALONSO FAJARDO    NYDIA SOLANGE
#
#                           CARGO  CIUDAD TELEFONO                Unnamed: 7
# 1  ESPECIALISTA DE AVIACION III  BOGOTA  4238530  RAFALE.ACOSTA@SATENA.COM
# 2   PROFESIONAL ESPECIALIZADO I  BOGOTA  4238530  JAVIER.ALFARO@SATENA.COM
# 3                    TECNICO II  BOGOTA  4238530   SOLANGEALONSO@GMAIL.COM
# C:\Users\Usuario\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %%
df['CIUDAD'].unique()[:6]
# Out:
# array(['BOGOTA', 'BARRANQUILL', 'MEDELLIN', 'QUIBDO'], dtype=object)

# %%
df['NOMBRES'].unique()[:30]
# Out:
# array(['MARIA LUISA', 'RAFALE ALFREDO', 'JAVIER GREGORIO',
#        'NYDIA SOLANGE', 'KAREN GISELLE', 'HECTOR ORLANDO',
#        'MARTHA ISABEL', 'AMANDA LUCIA', 'CARLOS ENRIQUE', 'JUAN CARLOS',
#        'HECTOR', 'KILTON HUMBERTO', 'DIANA ROCIO', 'KAROL DIANNE',
#        'ANGELA PATRICIA', 'LUIS GUILLERMO', 'MARIA MARLENE',
#        'NANCY MILENA', 'LUIS MIGUEL', 'JULY JENNETH', 'YICED DAYANA',
#        'VICTOR GUILLERMO', 'QUENA', 'HECTOR GERMAN', 'MARIA FERNANDA',
#        'RICARDO JOSE', 'JOHANNA PATRICIA', 'CARLOS ALBERTO',
#        'DANIEL EDUARDO', 'JAIRO'], dtype=object)

# %%
df['TELEFONO'].unique()[:2]
# Out:
# array([nan, 4238530], dtype=object)

# %%
df.reset_index()
# Out:
#      index  No.      CEDULA            APELLIDOS              NOMBRES  \
# 0        0    1    52049789        ACOSTA CASTRO          MARIA LUISA
# 1        1    2    93361475       ACOSTA RAMIREZ       RAFALE ALFREDO
# 2        2    3    79427921        ALFARO PATIÑO      JAVIER GREGORIO
# 3        3    4    52823876       ALONSO FAJARDO        NYDIA SOLANGE
# 4        4    5  1023869424      ALVAREZ FAJARDO        KAREN GISELLE
# 5        5    6    80394134    ALVAREZ MALDONADO       HECTOR ORLANDO
# 6        6    7    52203673         AMAYA CASTRO        MARTHA ISABEL
# 7        7    8    52172187         ANGEL OSORIO         AMANDA LUCIA
# 8        8    9    18203250               ARANGO       CARLOS ENRIQUE
# 9        9   10    79529340     ARDILA VELASQUEZ          JUAN CARLOS
# 10      10   11    12906217    ARELLANO PALACIOS               HECTOR
# 11      11   12    79291749    ARISTIZABAL GOMEZ          JUAN CARLOS
# ...

# %%
df.tail(150)
# Out:
#      No.      CEDULA            APELLIDOS              NOMBRES  \
# 161  162    80159601                NUÑEZ       EDGAR FERNANDO
# 162  163    79058663      OCAMPO MARTINEZ         CARLOS DAVID
# 163  164  1040733551     OCAMPO SOLORZANO               DANIEL
# 164  165    40988035        OCHOA MORALES     INDIRA ESMERALDA
# 165  166    51559249    ORJUELA GUTIERREZ                 AIDA
# 166  167  1032400161         ORTIZ GAITAN          EDWIN ORTIZ
# 167  168    43220241      ORTIZ JARAMILLO      SANDRA CATALINA
# 168  169    24336977          OSPINA LEON         PAULA ANDREA
# 169  170    53179391    PADILLA RODRIGUEZ       KELLY PATRICIA
# 170  171    52897309        PAZ VELASQUEZ         ELIDA LISBET
# 171  172  1152438268     PELAEZ HERNANDEZ      Diego Alejandro
# 172  173    52774981      PELAEZ PALACIOS       LIZ VEY ANDREA
# 173  174    79275021                 PEÑA         LUIS ALBERTO
# 174  175    79370823       PEÑA JARAMILLO        HUGO FERNANDI
# ...

# %%
df.iloc[0:10, :]
# Out:
#    No.      CEDULA          APELLIDOS          NOMBRES  \
# 0    1    52049789      ACOSTA CASTRO      MARIA LUISA
# 1    2    93361475     ACOSTA RAMIREZ   RAFALE ALFREDO
# 2    3    79427921      ALFARO PATIÑO  JAVIER GREGORIO
# 3    4    52823876     ALONSO FAJARDO    NYDIA SOLANGE
# 4    5  1023869424    ALVAREZ FAJARDO    KAREN GISELLE
# 5    6    80394134  ALVAREZ MALDONADO   HECTOR ORLANDO
# 6    7    52203673       AMAYA CASTRO    MARTHA ISABEL
# 7    8    52172187       ANGEL OSORIO     AMANDA LUCIA
# 8    9    18203250             ARANGO   CARLOS ENRIQUE
# 9   10    79529340   ARDILA VELASQUEZ      JUAN CARLOS
#
#                           CARGO  CIUDAD TELEFONO  \
# 0  AUXILIAR DE SERVICIO A BORDO  BOGOTA      NaN
# 1  ESPECIALISTA DE AVIACION III  BOGOTA  4238530
# 2   PROFESIONAL ESPECIALIZADO I  BOGOTA  4238530
# 3                    TECNICO II  BOGOTA  4238530
# 4   PROFESIONAL ESPECIALIZADO I  BOGOTA  4292300
# 5                   TECNICO III  BOGOTA  4238530
# ...

# %%
df.columns
# Out:
# Index(['No.', 'CEDULA', 'APELLIDOS', 'NOMBRES', 'CARGO', 'CIUDAD', 'TELEFONO',
#        'Unnamed: 7'],
#       dtype='object')

# %%
df['CIUDAD'].unique()[:5]
# Out:
# array(['BOGOTA', 'BARRANQUILL', 'MEDELLIN', 'QUIBDO'], dtype=object)

# %%
print("Funcion 1: \n {func1} \n Funcion 2: \n {func2} \n Funcion 3: \n{func3}".format(
        func1=df["CIUDAD"].unique(),func2=df["NOMBRES"].unique(),func3=df["TELEFONO"].unique()
        )
     )
# Out:
# Funcion 1:
#  ['BOGOTA' 'BARRANQUILL' 'MEDELLIN' 'QUIBDO']
#  Funcion 2:
#  ['MARIA LUISA' 'RAFALE ALFREDO' 'JAVIER GREGORIO' 'NYDIA SOLANGE'
#  'KAREN GISELLE' 'HECTOR ORLANDO' 'MARTHA ISABEL' 'AMANDA LUCIA'
#  'CARLOS ENRIQUE' 'JUAN CARLOS' 'HECTOR' 'KILTON HUMBERTO' 'DIANA ROCIO'
#  'KAROL DIANNE' 'ANGELA PATRICIA' 'LUIS GUILLERMO' 'MARIA MARLENE'
#  'NANCY MILENA' 'LUIS MIGUEL' 'JULY JENNETH' 'YICED DAYANA'
#  'VICTOR GUILLERMO' 'QUENA' 'HECTOR GERMAN' 'MARIA FERNANDA'
#  'RICARDO JOSE' 'JOHANNA PATRICIA' 'CARLOS ALBERTO' 'DANIEL EDUARDO'
#  'JAIRO' 'JULIETT ADRIANA' 'ANTONIO' 'JIMMY' 'YULI ANDREA'
#  'Myriam Janneth' 'ANGELA JANETH' 'DIANA MARCELA' 'MAURICIO ALEXANDER'
#  'GILBERTO ANTONIO' 'MILENA' 'JAVIER EDUARDO' 'Diana Marcela' 'SERGIO'
#  'LAURA ELIZABETH' 'ANA CAROLINA' 'WILMER FERNEY' 'MARCELA' 'JUANA MARÍA'
#  'BRIYID LORENA' 'JENNIFER TATIANA' 'Juan Carlos' 'MARTHA YOLANDA'
#  'JOSE GIOVANNI' 'JUAN CAMILO' 'RODOLFO ANTONIO' 'LUZ ESPERANZA'
# ...

# %%
pd.DataFrame(df, index=['1', '2', '3','4'])
# Out:
#    No.  CEDULA APELLIDOS NOMBRES CARGO CIUDAD TELEFONO Unnamed: 7
# 1  NaN     NaN       NaN     NaN   NaN    NaN      NaN        NaN
# 2  NaN     NaN       NaN     NaN   NaN    NaN      NaN        NaN
# 3  NaN     NaN       NaN     NaN   NaN    NaN      NaN        NaN
# 4  NaN     NaN       NaN     NaN   NaN    NaN      NaN        NaN

# %%
len(df)
# Out:
# 311

# %%
df['CIUDAD'].unique()[:5]
# Out:
# array(['BOGOTA', 'BARRANQUILL', 'MEDELLIN', 'QUIBDO'], dtype=object)

# %%
df['CARGO'].unique()[:35]
# Out:
# array(['AUXILIAR DE SERVICIO A BORDO', 'ESPECIALISTA DE AVIACION III',
#        'PROFESIONAL ESPECIALIZADO I', 'TECNICO II', 'TECNICO III',
#        'AUXILIAR', 'INSPECTOR TECNICO', 'PILOTO INSTRUCTOR', 'TECNICO I',
#        'JEFE DE TALLER', 'PROFESIONAL UNIVERSITARIO',
#        'DESPACHADOR DE AVIONES', 'COPILOTO',
#        'ESPECIALISTA DE AVIACION II', 'JEFE BASE AUXILIAR',
#        'JEFE DE GRUPO II', 'PROFESIONAL ESPEICIALIZADO I', 'PILOTO',
#        'OPERADOR DE RADIO', 'ESPECIALISTA AVIACION II',
#        'TECNICO ESPECIALISTA DE ABASTE', 'ESPECIALISTA AVIACION I',
#        'DIRECTOR', 'JEFE OFICINA ASESORA II',
#        'PROFESIONAL ESPECIALIZADO II', 'DESPACHADOR DE AVIONES INSTRU',
#        'JEFE DE GRUPO I', 'JEFE OFICINA ASESORA I',
#        'DESPACHADOR INSTRUCTOR', 'PRESIDENTE', 'VICEPRESIDENTE'],
#       dtype=object)

# %%
print(u'Seleccionamos filas y columnas')
print(df.loc[1:15, ['NOMBRES', 'CEDULA']])
# Out:
# Seleccionamos filas y columnas
#             NOMBRES      CEDULA
# 1    RAFALE ALFREDO    93361475
# 2   JAVIER GREGORIO    79427921
# 3     NYDIA SOLANGE    52823876
# 4     KAREN GISELLE  1023869424
# 5    HECTOR ORLANDO    80394134
# 6     MARTHA ISABEL    52203673
# 7      AMANDA LUCIA    52172187
# 8    CARLOS ENRIQUE    18203250
# 9       JUAN CARLOS    79529340
# 10           HECTOR    12906217
# 11      JUAN CARLOS    79291749
# 12  KILTON HUMBERTO    79277802
# 13      DIANA ROCIO    51783001
# 14     KAROL DIANNE  1022369340
# 15  ANGELA PATRICIA    52366223

# %%
print(u'Seleccionamos filas y columnas')
print(df.loc[1:100, ['CIUDAD','CARGO','TELEFONO']])
# Out:
# Seleccionamos filas y columnas
#           CIUDAD                         CARGO TELEFONO
# 1         BOGOTA  ESPECIALISTA DE AVIACION III  4238530
# 2         BOGOTA   PROFESIONAL ESPECIALIZADO I  4238530
# 3         BOGOTA                    TECNICO II  4238530
# 4         BOGOTA   PROFESIONAL ESPECIALIZADO I  4292300
# 5         BOGOTA                   TECNICO III  4238530
# 6         BOGOTA  AUXILIAR DE SERVICIO A BORDO      NaN
# 7         BOGOTA  AUXILIAR DE SERVICIO A BORDO      NaN
# 8         BOGOTA                      AUXILIAR  4238530
# 9         BOGOTA                    TECNICO II  4238530
# 10   BARRANQUILL  ESPECIALISTA DE AVIACION III     AN/A
# 11        BOGOTA             INSPECTOR TECNICO  4238530
# 12        BOGOTA             PILOTO INSTRUCTOR      NaN
# 13        BOGOTA                   TECNICO III  4292300
# 14        BOGOTA  AUXILIAR DE SERVICIO A BORDO      NaN
# 15        BOGOTA                     TECNICO I  4292300
# ...

# %%
df.to_html('PROYECTO_FINAL_JESS.html')
